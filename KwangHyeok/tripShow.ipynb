# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import pandas as pd
import datetime
import time

# %%
attractions = {
    'code' : [1168066000, 1168066000, 1168066000, 1168066000, 1168066000, 1168066000, 
              1174051500, 1174051500, 1174051500, 1174051500, 1174051500, 1174051500, 
              1130553500, 1130553500, 1130553500, 1130553500, 1130553500, 1130553500, 
              1150060300, 1150060300, 1150060300, 1150060300, 1150060300, 1150060300, 
              1162058500, 1162058500, 1162058500, 1162058500, 1162058500, 1162058500, 
              1121581000, 1121581000, 1121581000, 1121581000, 1121581000, 1121581000, 
              1153059500, 1153059500, 1153059500, 1153059500, 1153059500, 1153059500, 
              1154551000, 1154551000, 1154551000, 1154551000, 1154551000, 1154551000, 
              1135059500, 1135059500, 1135059500, 1135059500, 1135059500, 1135059500, 
              1132052100, 1132052100, 1132052100, 1132052100, 1132052100, 1132052100, 
              1123060000, 1123060000, 1123060000, 1123060000, 1123060000, 1123060000, 
              1159051000, 1159051000, 1159051000, 1159051000, 1159051000, 1159051000, 
              1144056500, 1144056500, 1144056500, 1144056500, 1144056500, 1144056500, 
              1141069000, 1141069000, 1141069000, 1141069000, 1141069000, 1141069000, 
              1165066000, 1165066000, 1165066000, 1165066000, 1165066000, 1165066000, 
              1120059000, 1120059000, 1120059000, 1120059000, 1120059000, 1120059000, 
              1129066000, 1129066000, 1129066000, 1129066000, 1129066000, 1129066000, 
              1171063100, 1171063100, 1171063100, 1171063100, 1171063100, 1171063100, 
              1147051000, 1147051000, 1147051000, 1147051000, 1147051000, 1147051000, 
              1156055000, 1156055000, 1156055000, 1156055000, 1156055000, 1156055000, 
              1117053000, 1117053000, 1117053000, 1117053000, 1117053000, 1117053000, 
              1138055100, 1138055100, 1138055100, 1138055100, 1138055100, 1138055100, 
              1111060000, 1111060000, 1111060000, 1111060000, 1111060000, 1111060000, 
              1114059000, 1114059000, 1114059000, 1114059000, 1114059000, 1114059000, 
              1126065500, 1126065500, 1126065500, 1126065500, 1126065500, 1126065500, ],
    'city' : ['강남구', '강남구', '강남구', '강남구', '강남구', '강남구', 
              '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', 
              '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', 
              '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', 
              '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', 
              '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', 
              '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', 
              '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', 
              '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', 
              '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', 
              '동대문구','동대문구','동대문구','동대문구','동대문구','동대문구',
              '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', 
              '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', 
              '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', 
              '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', 
              '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', 
              '성복구', '성복구', '성복구', '성복구', '성복구', '성복구', 
              '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', 
              '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', 
              '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', 
              '용산구', '용산구', '용산구', '용산구', '용산구', '용산구', 
              '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', 
              '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', 
              '중구', '중구', '중구', '중구', '중구', '중구', 
              '중랑구', '중랑구', '중랑구', '중랑구', '중랑구', '중랑구' ],
    'name' : [
        '코엑스 아쿠아리움', '스타필드 코엑스몰', '도산공원', '선릉과 정릉', '봉은사', '별마당 도서관',
        '일자산자연고원', '광나루한강공원', '서울 암사동 유적', '허브천문공원', '암사종합시장', '강풀만화거리',
        '북서울 꿈의숲', '삼각산 도선사', '대한불교조계종 화계사', '솔밭근린공원', '국립419민주묘지', '북한산',
        '서울식물원', '허준박물관', '방화근린공원', '국립항공박물관', '겸재정선미술관', '강서습지생태공원',
        '낙성대공원', '서울특별시교육청융합과학교육원', '서울대학교 박물관', '천주교 삼성산 성지', '호람박물관 신림본관', '관악산',
        '서울대공원', '서울상상나라', '뚝섬 야외수영장', '대한불교조계종 영화사', '유니버설아트센터', '아차산성',
        '푸른수목원', '고척스카이돔', '구로아트밸리 예술극장', '천왕 근린 공원', '디큐브링크아트센터', '구로시장',
        '대한불교조계종 호압사', '금천체육공원', '마리오아울렛', '금빛공원', '산기슭공원', '금천예술공장',
        '경춘선숲길', '육군사관학교', '학림사', '화랑대', '서울태릉과강릉', '서울생활사박물관',
        '서울창포원', '원당샘공원', '도봉산', '천축사', '원통사', '다락원 체육공원',
        '홍릉시험림', '영휘원과 숭인원', '동대문디자인플라자', '오미요리연구소', '청계천', '서울풍물시장',
        '보라매공원', '대한불교조계종 달마사', '효사정', '국립현총원 현충광', '보라매 안전 체험관', '노량진 수산물 도매시장',
        '하늘공원', '홍대난타극장', '서울이스케이프룸홍대2호점', '망원한강공원', '경의선숲길공원', '망원시장',
        '서대문형무소역사관', '한국불교태고종 봉원사', '서대문독립공원', '서대문자연사박물관', '홍제폭포', '이화여자대학교',
        '예술의전당', '국립국악원 예악당', '몽마르뜨공원', '세빛둥둥섬', '국립중앙도서관', '스파레이',
        '서울숲공원', '청계천박물관', 'N서울타워', '경복궁', '북촌 한옥마을', '살곶이다리',
        '대한불교조계종 길상사', '정릉', '한국가구박물관', '의릉', '만해 한용운 심우장', '성북구립미술관',
        '롯데월드', '올림픽공원', '석촌호수공원', '키자니아 서울', '한성백제박물관', '롯데월드 아쿠아리움',
        '서서울호수공원', '대한불교조계종 국제선센터', '신정산 계남근린공원', '양천공원', '신영시장', '오목공원',
        '여의도한강공원', '여의도공원', '타임스퀘어', '이랜드크루즈', 'CGV영등포', '63빌딩',
        '국립중앙박물관', '전쟁기념관', 'N서울타워', '리움미술관', '용산가족공원', '아이파크몰 용산점',
        '진관사', '은평한옥마을', '수국사', '은평 역사한옥 박물관', '삼천사', '사비나미술관',
        '경복궁', '북촌 한옥마을', '청계천', '광화문광장', '흥인지문', '광장시장',
        '덕수궁', '명동대성당', '동대문디자인플라자', '남대문시장', '한국은행 화폐박물관', '명동거리',
        '용마폭포공원', '중랑장미공원', '중랑캠핑숲', '봉화산', '용마랜드', 'N서울타워'
    ],
    'stars' : [
        '4.4', '4.2', '4.5', '4.6', '4.5', '4.6',
        '4.4', '4.4', '4.6', '4.5', '4.3', '3.5',
        '4.5', '4.4', '4.4', '4.4', '4.6', '4.7',
        '4.3', '4.3', '4.4', '4.6', '4.2', '4.2',
        '4.4', '4.2', '4.2', '4.5', '3.8', '4.5',
        '4.5', '4.6', '4.2', '4.3', '4.3', '4.4',
        '4.5', '4.4', '4.1', '4.4', '4.4', '3.8',
        '4.2', '4.3', '4.1', '4.1', '4.2', '4.1',
        '4.5', '4.3', '5.0', '4.0', '4.7', '4.4',
        '4.4', '4.2', '4.6', '4.1', '4.2', '4.4',
        '4.4', '4.3', '4.3', '5.0', '4.5', '3.9',
        '4.5', '4.4', '4.5', '4.6', '4.6', '3.9',
        '4.5', '4.6', '4.7', '4.5', '4.5', '4.3',
        '4.6', '4.4', '4.5', '4.3', '4.5', '4.6',
        '4.6', '4.5', '4.4', '4.2', '4.5', '4.2',
        '4.6', '4.3', '4.5', '4.6', '4.4', '4.2',
        '4.6', '4.5', '4.6', '4.5', '4.4', '4.5',
        '4.3', '4.6', '4.5', '4.3', '4.4', '4.3',
        '4.5', '4.4', '4.4', '4.5', '4.2', '4.2',
        '4.5', '4.4', '4.5', '4.2', '4.4', '4.2',
        '4.7', '4.6', '4.5', '4.6', '4.6', '4.4',
        '4.5', '4.2', '4.4', '4.1', '4.4', '4.3',
        '4.6', '4.4', '4.5', '4.4', '4.4', '4.2',
        '4.6', '4.7', '4.3', '4.2', '4.5', '4.3',
        '4.4', '4.3', '4.3', '4.5', '4.0', '4.5',
        ]
}

df_attractions = pd.DataFrame(attractions)

# %%
import oracledb as orcl
from sqlalchemy import create_engine
orcl.init_oracle_client()   # thick 드라이버로 변경

con = orcl.connect(
    user = 'jennie',
    password= '12345',
    dsn = 'localhost:1521/xe'
)

# %%
cur = con.cursor()
cur.execute("""
                CREATE TABLE attractions(
                    code NUMBER(15)
                        CONSTRAINT attractions_CODE_NN NOT NULL,
                    city VARCHAR2(10 CHAR)
                        CONSTRAINT attractions_city_NN NOT NULL,
                    name VARCHAR2(30 CHAR)
                        CONSTRAINT attractions_name_NN NOT NULL,
                    stars VARCHAR2(30 CHAR)
                        CONSTRAINT attractions_star_NN NOT NULL
                )
            """)
cur.execute('commit')
cur.close()

# %%
# 관광명소 데이터 삽입
path = 'oracle+oracledb://jennie:12345@localhost:1521/xe'
engine = create_engine(path)

table_name = 'attractions'  # 사용할 테이블 이름
df_attractions.to_sql(table_name, engine, if_exists='append', index=False)

print(f"Data has been inserted into table {table_name}")
# Out:
# Data has been inserted into table attractions
