# %%
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
# 폰트 설정
plt.rcParams['font.family'] = 'D2Coding'

# %%
# 다른 인코딩을 시도하여 파일 읽기
file_path1 = 'D:\study\ML\project\한국산업단지공단_공장등록 현황 통계정보_20230430.xlsx'
df1 = pd.read_excel(file_path1)  # 또는 'iso-8859-1', 'cp949' 등
df1
# Out:
# C:\Users\human\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    지역별 등록현황 Unnamed: 1
# 0                  NaN
# 1        구분      등록공장수
# 2     서울특별시      11160
# 3     부산광역시      10960
# 4     대구광역시       8384
# 5     인천광역시      13407
# 6     광주광역시       4701
# 7     대전광역시       3724
# 8     울산광역시       3081
# 9   세종특별자치시        798
# 10      경기도      74529
# 11      강원도       4046
# 12     충청북도       9589
# 13     충청남도      11633
# 14     전라북도       7578
# 15     전라남도       7842
# 16     경상북도      15873
# 17     경상남도      19919
# 18  제주특별자치도        738
# 19       합계     207962

# %%
file_path2 = 'D:\study\ML\project\환경부 국가미세먼지정보센터_국가 대기오염물질 배출량 통계_20211231.csv'
df2 = pd.read_csv(file_path2, encoding='EUC-KR')  # 또는 'iso-8859-1', 'cp949' 등
df2
# Out:
#           시도  시군구   일산화탄소(CO)  질소산화물(NOx)  황산화물(SOx)  총 부유입자(TSP)  \
# 0      서울특별시  종로구      8332.0      5982.0       62.0        186.0
# 1      서울특별시  종로구      4542.0     18169.0       66.0        129.0
# 2      서울특별시  종로구       819.0      2948.0       11.0          7.0
# 3      서울특별시  종로구      1405.0     13433.0       62.0         43.0
# 4      서울특별시  종로구        17.0       160.0        1.0          1.0
# ...      ...  ...         ...         ...        ...          ...
# 47116     바다   바다    435559.0   4620455.0    26163.0      88289.0
# 47117     바다   바다   2278657.0  24331746.0  3162099.0    1398911.0
# 47118     바다   바다     32186.0    344916.0    21747.0      26969.0
# 47119     바다   바다   5115094.0  54261568.0   253145.0    1036850.0
# 47120     바다   바다  38994481.0    638704.0      881.0     645488.0
#
#        미세먼지(PM-10)  초미세먼지(PM-2_5)  휘발성유기화합물(VOC)  암모니아(NH3)  블랙카본(BC)
# 0            186.0          186.0         1116.0      316.0      71.0
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns = ['구분',	'등록공장수']

# %%
df1
# Out:
#          구분  등록공장수
# 0     서울특별시  11160
# 1     부산광역시  10960
# 2     대구광역시   8384
# 3     인천광역시  13407
# 4     광주광역시   4701
# 5     대전광역시   3724
# 6     울산광역시   3081
# 7   세종특별자치시    798
# 8       경기도  74529
# 9       강원도   4046
# 10     충청북도   9589
# 11     충청남도  11633
# 12     전라북도   7578
# 13     전라남도   7842
# 14     경상북도  15873
# 15     경상남도  19919
# 16  제주특별자치도    738

# %%
df1 = df1.loc[2:, :]
df1.reset_index(drop=True, inplace=True)

# %%
df1 = df1.loc[0:16,:]
df1
# Out:
#          구분  등록공장수
# 0     서울특별시  11160
# 1     부산광역시  10960
# 2     대구광역시   8384
# 3     인천광역시  13407
# 4     광주광역시   4701
# 5     대전광역시   3724
# 6     울산광역시   3081
# 7   세종특별자치시    798
# 8       경기도  74529
# 9       강원도   4046
# 10     충청북도   9589
# 11     충청남도  11633
# 12     전라북도   7578
# 13     전라남도   7842
# 14     경상북도  15873
# 15     경상남도  19919
# 16  제주특별자치도    738

# %%
# 바 플롯 그리기
df1.plot(x='구분', y='등록공장수', kind='bar', figsize=(12, 8), legend=False)
plt.title('도시별 등록공장수')
plt.xlabel('도시')
plt.ylabel('등록공장수')
plt.xticks(rotation=45)
plt.show()

# %%
# 파이 차트 그리기
df1.set_index('구분').plot(kind='pie', y='등록공장수', autopct='%1.1f%%', figsize=(10, 10), legend=False)
plt.title('도시별 등록공장수 비율')
plt.ylabel('')  # 불필요한 y축 레이블 제거
plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_4676\1483278760.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.set_index('구분').plot(kind='pie', y='등록공장수', autopct='%1.1f%%', figsize=(10, 10), legend=False)

# %%
# 히스토그램 그리기
df1['등록공장수'].plot(kind='hist', bins=10, figsize=(10, 6))
plt.title('등록공장수 분포')
plt.xlabel('등록공장수')
plt.ylabel('빈도수')
plt.show()

# %%
# 라인 플롯 그리기
df1.plot(x='구분', y='등록공장수', kind='line', marker='o', figsize=(12, 8), legend=False)
plt.title('도시별 등록공장수 추이')
plt.xlabel('도시')
plt.ylabel('등록공장수')
plt.xticks(rotation=45)
plt.show()

# %%
df2
# Out:
#           시도  시군구   일산화탄소(CO)  질소산화물(NOx)  황산화물(SOx)  총 부유입자(TSP)  \
# 0      서울특별시  종로구      8332.0      5982.0       62.0        186.0
# 1      서울특별시  종로구      4542.0     18169.0       66.0        129.0
# 2      서울특별시  종로구       819.0      2948.0       11.0          7.0
# 3      서울특별시  종로구      1405.0     13433.0       62.0         43.0
# 4      서울특별시  종로구        17.0       160.0        1.0          1.0
# ...      ...  ...         ...         ...        ...          ...
# 47116     바다   바다    435559.0   4620455.0    26163.0      88289.0
# 47117     바다   바다   2278657.0  24331746.0  3162099.0    1398911.0
# 47118     바다   바다     32186.0    344916.0    21747.0      26969.0
# 47119     바다   바다   5115094.0  54261568.0   253145.0    1036850.0
# 47120     바다   바다  38994481.0    638704.0      881.0     645488.0
#
#        미세먼지(PM-10)  초미세먼지(PM-2_5)  휘발성유기화합물(VOC)  암모니아(NH3)  블랙카본(BC)
# 0            186.0          186.0         1116.0      316.0      71.0
# ...

# %%
soul = df2[df2['시도'] == '서울특별시']
soul.reset_index(drop=True, inplace=True)
soul
# Out:
#          시도  시군구  일산화탄소(CO)  질소산화물(NOx)  황산화물(SOx)  총 부유입자(TSP)  미세먼지(PM-10)  \
# 0     서울특별시  종로구     8332.0      5982.0       62.0        186.0        186.0
# 1     서울특별시  종로구     4542.0     18169.0       66.0        129.0        118.0
# 2     서울특별시  종로구      819.0      2948.0       11.0          7.0          6.0
# 3     서울특별시  종로구     1405.0     13433.0       62.0         43.0         43.0
# 4     서울특별시  종로구       17.0       160.0        1.0          1.0          1.0
# ...     ...  ...        ...         ...        ...          ...          ...
# 3688  서울특별시  강동구        5.0         3.0        1.0        145.0        145.0
# 3689  서울특별시  강동구    14358.0       132.0       13.0       1245.0        543.0
# 3690  서울특별시  강동구     1898.0        85.0        2.0         35.0         32.0
# 3691  서울특별시  강동구      125.0        20.0        0.0         18.0         15.0
# 3692  서울특별시  강동구      435.0        43.0        1.0         10.0          5.0
#
# ...

# %%
soul.describe().loc['mean', :]
# Out:
# 일산화탄소(CO)        12510.760000
# 질소산화물(NOx)       21045.121110
# 황산화물(SOx)          165.772921
# 총 부유입자(TSP)       7452.923006
# 미세먼지(PM-10)       2935.921158
# 초미세먼지(PM-2_5)      802.525716
# 휘발성유기화합물(VOC)    19295.399630
# 암모니아(NH3)         1061.116505
# 블랙카본(BC)           325.666010
# Name: mean, dtype: float64

# %%
soul2 = soul.iloc[:, 2:].mean()

# %%
soul2.columns = ['환경오염', '평균']
soul2
# Out:
# 일산화탄소(CO)        12510.760000
# 질소산화물(NOx)       21045.121110
# 황산화물(SOx)          165.772921
# 총 부유입자(TSP)       7452.923006
# 미세먼지(PM-10)       2935.921158
# 초미세먼지(PM-2_5)      802.525716
# 휘발성유기화합물(VOC)    19295.399630
# 암모니아(NH3)         1061.116505
# 블랙카본(BC)           325.666010
# dtype: float64

# %%
soule = pd.DataFrame(soul2)
soule
# Out:
#                           0
# 일산화탄소(CO)      12510.760000
# 질소산화물(NOx)     21045.121110
# 황산화물(SOx)        165.772921
# 총 부유입자(TSP)     7452.923006
# 미세먼지(PM-10)     2935.921158
# 초미세먼지(PM-2_5)    802.525716
# 휘발성유기화합물(VOC)  19295.399630
# 암모니아(NH3)       1061.116505
# 블랙카본(BC)         325.666010

# %%
# 데이터
data = {
    '환경오염': ['일산화탄소(CO)', '질소산화물(NOx)', '황산화물(SOx)', '총 부유입자(TSP)', 
               '미세먼지(PM-10)', '초미세먼지(PM-2_5)', '휘발성유기화합물(VOC)', 
               '암모니아(NH3)', '블랙카본(BC)'],
    '평균': [12510.760000, 21045.121110, 165.772921, 7452.923006, 2935.921158, 
           802.525716, 19295.399630, 1061.116505, 325.666010]
}

# 데이터프레임 생성
soule = pd.DataFrame(data)

# %%
soule.transpose()
# Out:
#               0            1           2            3            4  \
# 환경오염  일산화탄소(CO)   질소산화물(NOx)   황산화물(SOx)  총 부유입자(TSP)  미세먼지(PM-10)
# 평균     12510.76  21045.12111  165.772921  7452.923006  2935.921158
#
#                   5              6            7          8
# 환경오염  초미세먼지(PM-2_5)  휘발성유기화합물(VOC)    암모니아(NH3)   블랙카본(BC)
# 평균       802.525716    19295.39963  1061.116505  325.66601

# %%
# 데이터 생성
data = {
    '일산화탄소(CO)': [12510.76],
    '질소산화물(NOx)': [21045.12111],
    '황산화물(SOx)': [165.772921],
    '총 부유입자(TSP)': [7452.923006],
    '미세먼지(PM-10)': [2935.921158],
    '초미세먼지(PM-2_5)': [802.525716],
    '휘발성유기화합물(VOC)': [19295.39963],
    '암모니아(NH3)': [1061.116505],
    '블랙카본(BC)': [325.66601]
}

# 데이터프레임 생성
soule = pd.DataFrame(data)

# %%
soule
# Out:
#    일산화탄소(CO)   질소산화물(NOx)   황산화물(SOx)  총 부유입자(TSP)  미세먼지(PM-10)  \
# 0   12510.76  21045.12111  165.772921  7452.923006  2935.921158
#
#    초미세먼지(PM-2_5)  휘발성유기화합물(VOC)    암모니아(NH3)   블랙카본(BC)
# 0     802.525716    19295.39963  1061.116505  325.66601

# %%
korea = df2.groupby('시도')[['일산화탄소(CO)', '질소산화물(NOx)', '황산화물(SOx)', '총 부유입자(TSP)', '미세먼지(PM-10)', '초미세먼지(PM-2_5)', '휘발성유기화합물(VOC)', '암모니아(NH3)', '블랙카본(BC)']].mean()
korea
# Out:
#             일산화탄소(CO)    질소산화물(NOx)      황산화물(SOx)    총 부유입자(TSP)  \
# 시도
# 강원도      1.836922e+04  2.446025e+04    5484.971924    7306.292085
# 경기도      1.738639e+04  2.333455e+04     971.429797   11135.490569
# 경상남도     1.474358e+04  1.461845e+04    2883.911053    7463.010609
# 경상북도     2.432109e+04  2.029982e+04    4150.767267   11043.736332
# 광주광역시    9.609965e+03  1.503958e+04     176.552721    6898.840054
# 대구광역시    1.132332e+04  1.850490e+04    2292.591149    7648.820066
# 대전광역시    1.096827e+04  1.753450e+04     277.716443    6514.342593
# 바다       5.903016e+06  1.101782e+07  526074.750000  438119.250000
# 부산광역시    1.082446e+04  2.067256e+04    1152.123172    7955.047766
# 서울특별시    1.251076e+04  2.104512e+04     165.772921    7452.923006
# 세종특별자치시  2.585956e+04  2.397870e+04     432.040000   13317.434783
# 울산광역시    3.530307e+04  5.370471e+04   49927.310296    8733.579611
# 인천광역시    2.201079e+04  3.052546e+04    5585.063312   13326.667732
# ...

# %%
len(korea)
# Out:
# 18

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역별 등록현황    17 non-null     object
#  1   Unnamed: 1  17 non-null     object
# dtypes: object(2)
# memory usage: 400.0+ bytes

# %%
korea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 강원도 to 충청북도
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   일산화탄소(CO)      18 non-null     float64
#  1   질소산화물(NOx)     18 non-null     float64
#  2   황산화물(SOx)      18 non-null     float64
#  3   총 부유입자(TSP)    18 non-null     float64
#  4   미세먼지(PM-10)    18 non-null     float64
#  5   초미세먼지(PM-2_5)  18 non-null     float64
#  6   휘발성유기화합물(VOC)  18 non-null     float64
#  7   암모니아(NH3)      18 non-null     float64
#  8   블랙카본(BC)       18 non-null     float64
# dtypes: float64(9)
# memory usage: 1.4+ KB

# %%
korea.reset_index(drop=False, inplace=True)

# %%
korea
# Out:
#          시도     일산화탄소(CO)    질소산화물(NOx)      황산화물(SOx)    총 부유입자(TSP)  \
# 0       강원도  1.836922e+04  2.446025e+04    5484.971924    7306.292085
# 1       경기도  1.738639e+04  2.333455e+04     971.429797   11135.490569
# 2      경상남도  1.474358e+04  1.461845e+04    2883.911053    7463.010609
# 3      경상북도  2.432109e+04  2.029982e+04    4150.767267   11043.736332
# 4     광주광역시  9.609965e+03  1.503958e+04     176.552721    6898.840054
# 5     대구광역시  1.132332e+04  1.850490e+04    2292.591149    7648.820066
# 6     대전광역시  1.096827e+04  1.753450e+04     277.716443    6514.342593
# 7        바다  5.903016e+06  1.101782e+07  526074.750000  438119.250000
# 8     부산광역시  1.082446e+04  2.067256e+04    1152.123172    7955.047766
# 9     서울특별시  1.251076e+04  2.104512e+04     165.772921    7452.923006
# 10  세종특별자치시  2.585956e+04  2.397870e+04     432.040000   13317.434783
# 11    울산광역시  3.530307e+04  5.370471e+04   49927.310296    8733.579611
# ...

# %%
korea2 = korea[korea['시도'] != '바다']

# %%
korea2
# Out:
#          시도     일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  \
# 0       강원도  18369.215207  24460.246557   5484.971924   7306.292085
# 1       경기도  17386.394156  23334.547503    971.429797  11135.490569
# 2      경상남도  14743.579795  14618.447792   2883.911053   7463.010609
# 3      경상북도  24321.086678  20299.819791   4150.767267  11043.736332
# 4     광주광역시   9609.965465  15039.579580    176.552721   6898.840054
# 5     대구광역시  11323.317254  18504.903525   2292.591149   7648.820066
# 6     대전광역시  10968.268833  17534.498529    277.716443   6514.342593
# 8     부산광역시  10824.461235  20672.560867   1152.123172   7955.047766
# 9     서울특별시  12510.760000  21045.121110    165.772921   7452.923006
# 10  세종특별자치시  25859.557576  23978.696970    432.040000  13317.434783
# 11    울산광역시  35303.071611  53704.708861  49927.310296   8733.579611
# 12    인천광역시  22010.790497  30525.460545   5585.063312  13326.667732
# 13     전라남도  21003.670484  26375.466450  10226.610063   9641.104283
# ...

# %%
df1_sorted_asc = df1.sort_values(by='구분', ascending=True)
df1_sorted_asc.reset_index(drop=True, inplace=True)
df1_sorted_asc
# Out:
#          구분  등록공장수
# 0       강원도   4046
# 1       경기도  74529
# 2      경상남도  19919
# 3      경상북도  15873
# 4     광주광역시   4701
# 5     대구광역시   8384
# 6     대전광역시   3724
# 7     부산광역시  10960
# 8     서울특별시  11160
# 9   세종특별자치시    798
# 10    울산광역시   3081
# 11    인천광역시  13407
# 12     전라남도   7842
# 13     전라북도   7578
# 14  제주특별자치도    738
# 15     충청남도  11633
# 16     충청북도   9589

# %%
korea2_sorted_asc = korea2.sort_values(by='시도')
korea2_sorted_asc
# Out:
#          시도     일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  \
# 0       강원도  18369.215207  24460.246557   5484.971924   7306.292085
# 1       경기도  17386.394156  23334.547503    971.429797  11135.490569
# 2      경상남도  14743.579795  14618.447792   2883.911053   7463.010609
# 3      경상북도  24321.086678  20299.819791   4150.767267  11043.736332
# 4     광주광역시   9609.965465  15039.579580    176.552721   6898.840054
# 5     대구광역시  11323.317254  18504.903525   2292.591149   7648.820066
# 6     대전광역시  10968.268833  17534.498529    277.716443   6514.342593
# 8     부산광역시  10824.461235  20672.560867   1152.123172   7955.047766
# 9     서울특별시  12510.760000  21045.121110    165.772921   7452.923006
# 10  세종특별자치시  25859.557576  23978.696970    432.040000  13317.434783
# 11    울산광역시  35303.071611  53704.708861  49927.310296   8733.579611
# 12    인천광역시  22010.790497  30525.460545   5585.063312  13326.667732
# 13     전라남도  21003.670484  26375.466450  10226.610063   9641.104283
# ...

# %%
df1.set_index('구분')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4676\1435079814.py in ?()
# ----> 1 df1.set_index('구분')
#
# c:\Program Files\anaconda3\envs\py310\lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['구분'] are in the columns"

# %%
df1
# Out:
#          등록공장수
# 구분
# 서울특별시    11160
# 부산광역시    10960
# 대구광역시     8384
# 인천광역시    13407
# 광주광역시     4701
# 대전광역시     3724
# 울산광역시     3081
# 세종특별자치시    798
# 경기도      74529
# 강원도       4046
# 충청북도      9589
# 충청남도     11633
# 전라북도      7578
# 전라남도      7842
# 경상북도     15873
# 경상남도     19919
# 제주특별자치도    738

# %%
df2 = korea2_sorted_asc.set_index('시도')

# %%
df2
# Out:
#             일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  미세먼지(PM-10)  \
# 시도
# 강원도      18369.215207  24460.246557   5484.971924   7306.292085  2938.197765
# 경기도      17386.394156  23334.547503    971.429797  11135.490569  4021.233683
# 경상남도     14743.579795  14618.447792   2883.911053   7463.010609  2623.206016
# 경상북도     24321.086678  20299.819791   4150.767267  11043.736332  4175.161234
# 광주광역시     9609.965465  15039.579580    176.552721   6898.840054  2210.978495
# 대구광역시    11323.317254  18504.903525   2292.591149   7648.820066  2564.574627
# 대전광역시    10968.268833  17534.498529    277.716443   6514.342593  2104.033113
# 부산광역시    10824.461235  20672.560867   1152.123172   7955.047766  3212.418769
# 서울특별시    12510.760000  21045.121110    165.772921   7452.923006  2935.921158
# 세종특별자치시  25859.557576  23978.696970    432.040000  13317.434783  4631.543478
# 울산광역시    35303.071611  53704.708861  49927.310296   8733.579611  3944.028835
# ...

# %%
result = pd.concat([df1, df2], axis=1)
result
# Out:
#          등록공장수     일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  \
# 서울특별시    11160  12510.760000  21045.121110    165.772921   7452.923006
# 부산광역시    10960  10824.461235  20672.560867   1152.123172   7955.047766
# 대구광역시     8384  11323.317254  18504.903525   2292.591149   7648.820066
# 인천광역시    13407  22010.790497  30525.460545   5585.063312  13326.667732
# 광주광역시     4701   9609.965465  15039.579580    176.552721   6898.840054
# 대전광역시     3724  10968.268833  17534.498529    277.716443   6514.342593
# 울산광역시     3081  35303.071611  53704.708861  49927.310296   8733.579611
# 세종특별자치시    798  25859.557576  23978.696970    432.040000  13317.434783
# 경기도      74529  17386.394156  23334.547503    971.429797  11135.490569
# 강원도       4046  18369.215207  24460.246557   5484.971924   7306.292085
# 충청북도      9589  17767.758989  23237.803493   3651.673160   9664.254125
# 충청남도     11633  24970.276403  28683.636849  15635.055351  11951.129912
# ...

# %%
result.reset_index(drop=False, inplace=True)

# %%
result[0].columns = result['시도']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\anaconda3\envs\py310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '시도'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 result[0].columns = result['시도']
#
# ...

# %%
result.rename(columns={'index': '시도'}, inplace=True)

# %%
result
# Out:
#          시도  등록공장수     일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  \
# 0     서울특별시  11160  12510.760000  21045.121110    165.772921   7452.923006
# 1     부산광역시  10960  10824.461235  20672.560867   1152.123172   7955.047766
# 2     대구광역시   8384  11323.317254  18504.903525   2292.591149   7648.820066
# 3     인천광역시  13407  22010.790497  30525.460545   5585.063312  13326.667732
# 4     광주광역시   4701   9609.965465  15039.579580    176.552721   6898.840054
# 5     대전광역시   3724  10968.268833  17534.498529    277.716443   6514.342593
# 6     울산광역시   3081  35303.071611  53704.708861  49927.310296   8733.579611
# 7   세종특별자치시    798  25859.557576  23978.696970    432.040000  13317.434783
# 8       경기도  74529  17386.394156  23334.547503    971.429797  11135.490569
# 9       강원도   4046  18369.215207  24460.246557   5484.971924   7306.292085
# 10     충청북도   9589  17767.758989  23237.803493   3651.673160   9664.254125
# ...

# %%
# 라인 플롯 그리기
plt.plot(x='시도', y='등록공장수', kind='line', marker='o', figsize=(12, 8), legend=False)
plt.plot(x='시도', y='미세먼지(PM-10)', kind='line', marker='o', figsize=(12, 8), legend=False)
plt.plot(x='시도', y='초미세먼지(PM-2_5)', kind='line', marker='o', figsize=(12, 8), legend=False)
plt.title('도시별 공장과 미세먼지의 관련도 조사')
plt.xlabel('도시')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(result['시도'], result['등록공장수'], color='y', marker='*', markersize=2, label='공장 개수')
plt.plot(result['시도'], result['미세먼지(PM-10)'], color='r', marker='^', markersize=2, label='미세먼지 농도')
plt.plot(result['시도'], result['초미세먼지(PM-2_5)'], color='purple', marker='D', markersize=2, label='초미세먼지 농도')
plt.xticks(result['시도'], rotation=90)
plt.grid(True)
plt.legend()
plt.show()

# %%
result.describe()
# Out:
#               등록공장수     일산화탄소(CO)    질소산화물(NOx)     황산화물(SOx)   총 부유입자(TSP)  \
# count     17.000000     17.000000     17.000000     17.000000     17.000000
# mean   12233.058824  22276.400220  25008.972110   6318.121574  10408.869534
# std    16887.857726  17833.467576  11017.695353  11941.641649   4670.077852
# min      738.000000   9609.965465  13998.471889    165.772921   6514.342593
# 25%     4046.000000  12510.760000  18504.903525    971.429797   7463.010609
# 50%     8384.000000  17767.758989  23237.803493   2839.000000   9641.104283
# 75%    11633.000000  24321.086678  26375.466450   5484.971924  11135.490569
# max    74529.000000  86270.869403  53704.708861  49927.310296  26425.990683
#
#        미세먼지(PM-10)  초미세먼지(PM-2_5)  휘발성유기화합물(VOC)     암모니아(NH3)    블랙카본(BC)
# count    17.000000      17.000000      17.000000     17.000000   17.000000
# mean   3732.986424    1453.329467   29265.929664   8239.061602  327.462043
# ...

# %%
result[['등록공장수', '일산화탄소(CO)', '질소산화물(NOx)', '황산화물(SOx)',	'총 부유입자(TSP)',	'미세먼지(PM-10)', '초미세먼지(PM-2_5)', '휘발성유기화합물(VOC)',	'암모니아(NH3)',	'블랙카본(BC)']].corr()
# Out:
#                   등록공장수  일산화탄소(CO)  질소산화물(NOx)  황산화물(SOx)  총 부유입자(TSP)  \
# 등록공장수          1.000000  -0.189415   -0.167054  -0.161285    -0.053625
# 일산화탄소(CO)     -0.189415   1.000000    0.780420   0.219947     0.922033
# 질소산화물(NOx)    -0.167054   0.780420    1.000000   0.712958     0.594310
# 황산화물(SOx)     -0.161285   0.219947    0.712958   1.000000    -0.045383
# 총 부유입자(TSP)   -0.053625   0.922033    0.594310  -0.045383     1.000000
# 미세먼지(PM-10)   -0.048551   0.952124    0.703931   0.089882     0.979373
# 초미세먼지(PM-2_5) -0.164068   0.960628    0.831050   0.361817     0.877953
# 휘발성유기화합물(VOC) -0.124391   0.557863    0.845642   0.842219     0.352847
# 암모니아(NH3)     -0.184907   0.789037    0.674817   0.433317     0.726631
# 블랙카본(BC)       0.021876   0.865743    0.635180   0.053077     0.910028
#
#                미세먼지(PM-10)  초미세먼지(PM-2_5)  휘발성유기화합물(VOC)  암모니아(NH3)  블랙카본(BC)
# 등록공장수            -0.048551      -0.164068      -0.124391  -0.184907  0.021876
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   시도             17 non-null     object
#  1   등록공장수          17 non-null     float64
#  2   일산화탄소(CO)      17 non-null     float64
#  3   질소산화물(NOx)     17 non-null     float64
#  4   황산화물(SOx)      17 non-null     float64
#  5   총 부유입자(TSP)    17 non-null     float64
#  6   미세먼지(PM-10)    17 non-null     float64
#  7   초미세먼지(PM-2_5)  17 non-null     float64
#  8   휘발성유기화합물(VOC)  17 non-null     float64
#  9   암모니아(NH3)      17 non-null     float64
#  10  블랙카본(BC)       17 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 1.6+ KB

# %%
result['등록공장수'] = result['등록공장수'].astype(float)
